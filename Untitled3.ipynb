# %% [markdown]
# <a href="https://colab.research.google.com/github/iannnnjaja/primera-clase/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.¿Qué es la memoria RAM?
# Memoria temporal donde se guardan los datos y programas que la computadora está usando en ese momento. Se borra al apagar.
#
# ¿Qué es la CPU?
# Es el “cerebro” de la computadora; ejecuta instrucciones y procesa datos.
#
# ¿En qué partes se divide la CPU?
# Unidad de Control (CU)
# Unidad Aritmético-Lógica (ALU)
# Registros
#
# Diferencia entre constantes y variables en Python
# Variable: puede cambiar su valor (x = 5, luego x = 10)
# Constante: su valor no debería cambiar (por convención en mayúsculas: PI = 3.14)
#
#
# ¿Python es fuertemente tipificado?
# Sí, porque no puedes mezclar tipos sin conversión (ej: no puedes sumar texto + número directamente).
#
#
# ¿Qué es un algoritmo?
# Conjunto de pasos ordenados para resolver un problema.
#
#
# ¿Qué es un diagrama de flujo?
# Representación gráfica de un a
# lgoritmo usando símbolos.
#
#
# Diferencia entre lenguaje compilado e interpretado
# Compilado: se traduce todo antes de ejecutarse (ej: C)
# Interpretado: se ejecuta línea por línea (ej: Python)
#
#
# ¿Qué es una computadora?
# Máquina que recibe datos
# , los procesa y genera resultados.
#
#
# ¿Cuántos tipos de periféricos hay?
# 3 tipos:
# Entrada
# Salida
# Entrada/Salida
